# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (3.0.2)
# Requirement already satisfied: filelock in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (0.26.1)
# Requirement already satisfied: packaging in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from aiohttp->datasets) (1.15.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
# Out:
# 2024-11-03 15:04:57.254654: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Take in sample dataframe

# %%
bad_df = pd.read_csv("data/sample_bad.csv")
bad_df['label'] = 0
bad_df = bad_df[["link", "text", "label"]]
bad_df
# Out:
#                                                  link  \
# 0              https://doi.org/10.1021%2Fjacs.5b04930
# 1               https://doi.org/10.1038%2Fnature14133
# 2               https://doi.org/10.1557%2Fmrc.2015.26
# 3   https://doi.org/10.1016%2F0927-0256%2896%29000...
# 4       https://doi.org/10.1021%2Facs.jpclett.6b02684
# 5            https://doi.org/10.1002%2Faenm.201601079
# 6     https://doi.org/10.1021%2Facsenergylett.6b00002
# 7                 https://doi.org/10.1063%2F1.2903699
# 8      https://doi.org/10.1016%2Fj.solmat.2013.05.052
# 9   https://doi.org/10.4028%2Fwww.scientific.net%2...
# 10                 https://doi.org/10.1038%2Fnmat4014
# 11          https://doi.org/10.1038%2Fnenergy.2016.93
# 12     https://doi.org/10.1021%2Facs.nanolett.6b05177
# 13       https://doi.org/10.1038%2Fs41467-017-00516-5
# 14              https://doi.org/10.1038%2Fncomms16045
# 15       https://doi.org/10.1038%2Fnatrevmats.2018.17
# 16               https://doi.org/10.1039%2FC7TA01441D
# 17        https://doi.org/10.1103%2FPhysRevB.54.11169
# 18                https://doi.org/10.1063%2F1.2973398
# 19                https://doi.org/10.1021%2Fnl501838y
#
#                                                  text  label
# 0                               HTTP Error, No Access      0
# 1   Compositional engineering of perovskite materi...      0
# 2   Identifying defect-tolerant semiconductors wit...      0
# 3                                         Redirecting      0
# 4                               HTTP Error, No Access      0
# 5                               HTTP Error, No Access      0
# 6                               HTTP Error, No Access      0
# 7   Effect of strain compensation on quantum dot e...      0
# 8                                         Redirecting      0
# 9   Stress Gradient Analysis by Noncomplanar x-Ray...      0
# 10  Solvent engineering for high-performance inorg...      0
# 11  Facet-dependent photovoltaic efficiency variat...      0
# 12                              HTTP Error, No Access      0
# 13  Strain-engineered growth of two-dimensional ma...      0
# 14  Meniscus-assisted solution printing of large-g...      0
# 15  Scalable fabrication of perovskite solar cells...      0
# 16  The intrinsic properties of FA(1−x)MAxPbI3 per...      0
# 17                              HTTP Error, No Access      0
# 18  Strain-compensated InAs/GaNAs quantum dots for...      0
# 19                              HTTP Error, No Access      0

# %%
pass_bad_df = bad_df[(bad_df['text'] != "HTTP Error, No Access") & (bad_df['text'] != "Redirecting")]
pass_bad_df
# Out:
#                                                  link  \
# 1               https://doi.org/10.1038%2Fnature14133
# 2               https://doi.org/10.1557%2Fmrc.2015.26
# 7                 https://doi.org/10.1063%2F1.2903699
# 9   https://doi.org/10.4028%2Fwww.scientific.net%2...
# 10                 https://doi.org/10.1038%2Fnmat4014
# 11          https://doi.org/10.1038%2Fnenergy.2016.93
# 13       https://doi.org/10.1038%2Fs41467-017-00516-5
# 14              https://doi.org/10.1038%2Fncomms16045
# 15       https://doi.org/10.1038%2Fnatrevmats.2018.17
# 16               https://doi.org/10.1039%2FC7TA01441D
# 18                https://doi.org/10.1063%2F1.2973398
#
#                                                  text  label
# 1   Compositional engineering of perovskite materi...      0
# 2   Identifying defect-tolerant semiconductors wit...      0
# 7   Effect of strain compensation on quantum dot e...      0
# 9   Stress Gradient Analysis by Noncomplanar x-Ray...      0
# 10  Solvent engineering for high-performance inorg...      0
# 11  Facet-dependent photovoltaic efficiency variat...      0
# 13  Strain-engineered growth of two-dimensional ma...      0
# 14  Meniscus-assisted solution printing of large-g...      0
# 15  Scalable fabrication of perovskite solar cells...      0
# 16  The intrinsic properties of FA(1−x)MAxPbI3 per...      0
# 18  Strain-compensated InAs/GaNAs quantum dots for...      0

# %%
good_df = pd.read_csv("data/sample_good.csv")
good_df['label'] = 1
good_df
# Out:
#                                                  link  \
# 0   https://www.nature.com/articles/s41560-018-0200-6
# 1        https://doi.org/10.1038%2Fs41586-021-03406-5
# 2   https://www.science.org/doi/10.1126/science.ab...
# 3        https://doi.org/10.1038%2Fs41560-023-01204-z
# 4       https://pubs.acs.org/doi/10.1021/jacs.5b11740
# 5            https://doi.org/10.1002%2Faenm.201803699
# 6           https://doi.org/10.1126%2Fscience.adg3755
# 7        https://doi.org/10.1038%2Fs41586-021-03285-w
# 8        https://doi.org/10.1038%2Fs41566-022-00985-1
# 9                https://doi.org/10.1039%2FC9TA06058H
# 10               https://doi.org/10.1039%2FC8TC04871A
# 11           https://doi.org/10.1002%2Fanie.201406466
# 12    https://doi.org/10.1021%2Facsenergylett.7b00442
# 13  https://pubs.rsc.org/en/content/articlehtml/20...
# 14       https://doi.org/10.1038%2Fs41560-023-01295-8
# 15  https://www.sciencedirect.com/science/article/...
# 16      https://pubs.acs.org/doi/10.1021/jacs.0c01704
# 17          https://doi.org/10.1126%2Fscience.abj2637
# 18          https://doi.org/10.1126%2Fscience.add7331
# 19           https://doi.org/10.1002%2Fadma.201600969
#
#                                                  text  label
# 0   A fluorene-terminated hole-transporting materi...      1
# 1   Pseudo-halide anion engineering for α-FAPbI3 p...      1
# 2                               HTTP Error, No Access      1
# 3   Expanding the low-dimensional interface engine...      1
# 4                               HTTP Error, No Access      1
# 5                               HTTP Error, No Access      1
# 6                               HTTP Error, No Access      1
# 7   Efficient perovskite solar cells via improved ...      1
# 8   Quantum-size-tuned heterostructures enable eff...      1
# 9   Thermal degradation of formamidinium based lea...      1
# 10  Amine additive reactions induced by the soft L...      1
# 11                              HTTP Error, No Access      1
# 12                              HTTP Error, No Access      1
# 13  Stable perovskite solar cells using tin acetyl...      1
# 14  2D/3D heterojunction engineering at the buried...      1
# 15                              HTTP Error, No Access      1
# 16                              HTTP Error, No Access      1
# 17                              HTTP Error, No Access      1
# 18                              HTTP Error, No Access      1
# 19                              HTTP Error, No Access      1

# %%
pass_good_df = good_df[good_df['text'] != "HTTP Error, No Access"]
pass_good_df
# Out:
#                                                  link  \
# 0   https://www.nature.com/articles/s41560-018-0200-6
# 1        https://doi.org/10.1038%2Fs41586-021-03406-5
# 3        https://doi.org/10.1038%2Fs41560-023-01204-z
# 7        https://doi.org/10.1038%2Fs41586-021-03285-w
# 8        https://doi.org/10.1038%2Fs41566-022-00985-1
# 9                https://doi.org/10.1039%2FC9TA06058H
# 10               https://doi.org/10.1039%2FC8TC04871A
# 13  https://pubs.rsc.org/en/content/articlehtml/20...
# 14       https://doi.org/10.1038%2Fs41560-023-01295-8
#
#                                                  text  label
# 0   A fluorene-terminated hole-transporting materi...      1
# 1   Pseudo-halide anion engineering for α-FAPbI3 p...      1
# 3   Expanding the low-dimensional interface engine...      1
# 7   Efficient perovskite solar cells via improved ...      1
# 8   Quantum-size-tuned heterostructures enable eff...      1
# 9   Thermal degradation of formamidinium based lea...      1
# 10  Amine additive reactions induced by the soft L...      1
# 13  Stable perovskite solar cells using tin acetyl...      1
# 14  2D/3D heterojunction engineering at the buried...      1

# %% [markdown]
# # Combine these two dataframe

# %%
# merged_df = pass_good_df.append(pass_bad_df, ignore_index=True)[['text', 'label']]
# merged_df

merged_df = pd.concat([pass_good_df, pass_bad_df], ignore_index=True)[['text', 'label']]
merged_df
# Out:
#                                                  text  label
# 0   A fluorene-terminated hole-transporting materi...      1
# 1   Pseudo-halide anion engineering for α-FAPbI3 p...      1
# 2   Expanding the low-dimensional interface engine...      1
# 3   Efficient perovskite solar cells via improved ...      1
# 4   Quantum-size-tuned heterostructures enable eff...      1
# 5   Thermal degradation of formamidinium based lea...      1
# 6   Amine additive reactions induced by the soft L...      1
# 7   Stable perovskite solar cells using tin acetyl...      1
# 8   2D/3D heterojunction engineering at the buried...      1
# 9   Compositional engineering of perovskite materi...      0
# 10  Identifying defect-tolerant semiconductors wit...      0
# 11  Effect of strain compensation on quantum dot e...      0
# 12  Stress Gradient Analysis by Noncomplanar x-Ray...      0
# 13  Solvent engineering for high-performance inorg...      0
# 14  Facet-dependent photovoltaic efficiency variat...      0
# 15  Strain-engineered growth of two-dimensional ma...      0
# 16  Meniscus-assisted solution printing of large-g...      0
# 17  Scalable fabrication of perovskite solar cells...      0
# 18  The intrinsic properties of FA(1−x)MAxPbI3 per...      0
# 19  Strain-compensated InAs/GaNAs quantum dots for...      0

# %%
pip install --upgrade accelerate
# Out:
# Requirement already satisfied: accelerate in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from accelerate) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from accelerate) (2.2.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from accelerate) (0.26.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.9.0)
# Requirement already satisfied: requests in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

data = pd.read_csv("data/merged_label.csv")

data = data[['text', 'label']]

dataset = Dataset.from_pandas(data)

train_test_split = dataset.train_test_split(test_size=0.2)

tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")
model = AutoModelForSequenceClassification.from_pretrained("allenai/scibert_scivocab_uncased", num_labels=2)

def tokenize_function(examples):
    return tokenizer(examples['text'], truncation=True, padding='max_length', max_length=512)

tokenized_dataset = train_test_split.map(tokenize_function, batched=True)

training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
)

def compute_metrics(p):
    preds = p.predictions.argmax(axis=1)
    precision, recall, f1, _ = precision_recall_fscore_support(p.label_ids, preds, average='binary')
    acc = accuracy_score(p.label_ids, preds)
    return {"accuracy": acc, "precision": precision, "recall": recall, "f1": f1}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset['train'],
    eval_dataset=tokenized_dataset['test'],
    compute_metrics=compute_metrics,
)

trainer.train()

results = trainer.evaluate()
print(results)

predictions = trainer.predict(tokenized_dataset['test'])
pred_labels = predictions.predictions.argmax(axis=1)
true_labels = predictions.label_ids

output_df = pd.DataFrame({'Text': tokenized_dataset['test']['text'], 'True Label': true_labels, 'Predicted Label': pred_labels})
print(output_df)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at allenai/scibert_scivocab_uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/105 [00:00<?, ? examples/s]
# Map:   0%|          | 0/27 [00:00<?, ? examples/s]
# /Users/dpark_23/anaconda3/envs/DSC180/lib/python3.8/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='21' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21/21 35:06, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.578924</td>
#       <td>0.703704</td>
#       <td>0.647059</td>
#       <td>0.846154</td>
#       <td>0.733333</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.578327</td>
#       <td>0.703704</td>
#       <td>0.666667</td>
#       <td>0.769231</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.597991</td>
#       <td>0.703704</td>
#       <td>0.666667</td>
#       <td>0.769231</td>
#       <td>0.714286</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 0.5979912877082825, 'eval_accuracy': 0.7037037037037037, 'eval_precision': 0.6666666666666666, 'eval_recall': 0.7692307692307693, 'eval_f1': 0.7142857142857142, 'eval_runtime': 25.8684, 'eval_samples_per_second': 1.044, 'eval_steps_per_second': 0.077, 'epoch': 3.0}
#                                                  Text  True Label  \
# 0   Imaging and quantifying non-radiative losses a...           1
# 1   Surface passivation of perovskite film for eff...           1
# 2   Anion–π interactions suppress phase impurities...           1
# 3   Large guanidinium cation mixed with methylammo...           0
# 4   Temporal and spatial pinhole constraints in sm...           1
# 5   Analysis of Macromolecular Polydispersity in I...           0
# 6   Multication perovskite 2D/3D interfaces form v...           1
# 7   The intrinsic properties of FA(1−x)MAxPbI3 per...           0
# 8   Strain engineering in perovskite solar cells a...           1
# 9   Polymer-templated nucleation and crystal growt...           1
# 10  Ionic transport in hybrid lead iodide perovski...           1
# 11  Loss of pyruvate kinase M2 limits growth and t...           0
# 12  Stability-limiting heterointerfaces of perovsk...           1
# 13  Effect of strain compensation on quantum dot e...           0
# 14  Scalable fabrication of perovskite solar cells...           0
# 15  Oriented nucleation in formamidinium perovskit...           0
# 16  Meniscus-assisted solution printing of large-g...           0
# 17  Aggregation of superparamagnetic colloids in m...           0
# 18  [2102.10399] Molecular Dynamics Simulations of...           0
# 19  Expanding the low-dimensional interface engine...           1
# 20  Stabilization of 3D/2D perovskite heterostruct...           1
# 21  Strain-engineered growth of two-dimensional ma...           0
# 22  Dynamical evolution of the 2D/3D interface: a ...           1
# 23  Ammonia for post-healing of formamidinium-base...           1
# 24  Measurement of small electrophoretic mobilitie...           0
# 25  The general theory of molecular forces - Trans...           0
# 26  Formamidinium lead trihalide: a broadly tunabl...           0
#
#     Predicted Label
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 0
# 5                 0
# 6                 1
# 7                 0
# 8                 1
# 9                 1
# 10                0
# 11                1
# 12                1
# 13                0
# 14                0
# 15                1
# 16                1
# 17                0
# 18                0
# 19                1
# 20                1
# 21                1
# 22                0
# 23                1
# 24                0
# 25                0
# 26                0

# %%
# from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# # Convert DataFrame to Hugging Face Dataset
# dataset = Dataset.from_pandas(merged_df)

# train_test_split = dataset.train_test_split(test_size=0.2)

# # Load SciBERT tokenizer
# tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")
# model = AutoModelForSequenceClassification.from_pretrained("allenai/scibert_scivocab_uncased", num_labels=2)

# def compute_metrics(pred):
#     labels = pred.label_ids
#     preds = pred.predictions.argmax(-1)
#     precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
#     acc = accuracy_score(labels, preds)
#     return {
#         'accuracy': acc,
#         'f1': f1,
#         'precision': precision,
#         'recall': recall
#     }
    
# # Tokenize the text
# def tokenize_function(examples):
#     return tokenizer(examples['text'], truncation=True, padding='max_length', max_length = 512)

# tokenized_dataset = train_test_split.map(tokenize_function, batched=True)
# #tokenized_dataset = dataset.map(tokenize_function, batched=True)
# tokenized_dataset

# # Define training arguments
# training_args = TrainingArguments(
#     output_dir='./results',
#     evaluation_strategy="epoch",
#     learning_rate=1e-5,
#     per_device_train_batch_size=16,
#     per_device_eval_batch_size=16,
#     num_train_epochs=3,
#     weight_decay=0.01,
# )

# # Trainer to handle the fine-tuning process
# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=tokenized_dataset['train'],
#     eval_dataset=tokenized_dataset['test'],
#     compute_metrics=compute_metrics
# )

# # Fine-tune SciBERT
# trainer.train()

# %%
# predictions = trainer.predict(tokenized_dataset['test'])
# predicted_labels = predictions.predictions.argmax(-1)
# print(predicted_labels)  # To see predicted labels (0 or 1)

# %%
# test_texts = tokenized_dataset['test']['text']
# results = [{'text': text, 'predicted_label': label} for text, label in zip(test_texts, predicted_labels)]
# for result in results:
#     print(result)
