# %%
import xml.etree.ElementTree as ET 
import pandas as pd 
import os

# %%
def parse_bioc(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    
    data = { }
    concept_ids = set()
    relations = {}
    for relation in root.findall(".//relation"):
        test_name = relation.find("infon[@key='type']").text
        node_ids = [node.get("refid") for node in relation.findall("node")]
        for node_id in node_ids:
            relations[node_id] = test_name

    for annotation in root.findall(".//annotation"):
        node_id = annotation.get("id")
        var_name = annotation.find("infon[@key='type']").text
        concept_id = annotation.find("infon[@key='identifier']").text
        value = annotation.find("text").text
        if node_id in relations:
            stability_test = relations[node_id]
            if stability_test not in data:
                data[stability_test] = {}
            if concept_id is None:
                concept_id = value
            data[stability_test][var_name] = concept_id
            concept_ids.add(concept_id)

        if concept_id is None:
            concept_id = value
        if concept_id in concept_ids: # duplicate annotation
            continue
        concept_ids.add(concept_id)
        if var_name not in data:
            data[var_name] = concept_id
        else:
            if isinstance(data[var_name], list):
                data[var_name].append(value)
            else:
                data[var_name] = [data[var_name], value]
    
    return data

# %%
bioc_dir = "../../data/biocs"
data = []
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        row = parse_bioc(file_path)
        if len(row.keys()) > 0:
            data.append(row)
print(data)
df = pd.DataFrame(data)
df.head()
# Out:
# [{'ISOSL3': {'control_pce': '24', 'efficiency_tret': '95%', 'time': '1200', 'treated_pce': '26.9', 'treated_voc': '1.18'}, 'structure_pin_nip': 'PIN', 'passivating_molecule': '4Cl-BZS', 'perovskite_composition': 'Cs 0.05 FA 0.85 MA 0.1 PbI 3', 'hole_transport_layer': '2PACz and Me-4PACz', 'electron_transport_layer': 'C60', 'journal_publication': ['Science', 'science'], 'date_published': '4/11/2024'}, {'ISOSD2': {'treated_pce': '23.32', 'treated_voc': '1.16', 'control_pce': '21.3', 'time': '500'}, 'passivating_molecule': 'phenethylammonium iodide (PEAI)', 'electron_transport_layer': ['HC(NH 2 ) 2 -CH 3 NH 3', 'SnO 2'], 'journal_publication': 'nature', 'hole_transport_layer': 'spiro-OMeTAD', 'date_published': '1 April 2019'}, {'treated_voc': '1.185', 'ISOSD1': {'treated_voc': '1.185', 'temperature': '85', 'humidity': '85', 'treated_pce': '24.35', 'time': '1056', 'control_pce': '22.39'}, 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'humidity': '85', 'perovskite_composition': '(C 4 H 9 NH 3 ) 2 PbI 4', 'efficiency_tret': '94', 'passivating_molecule': '(CH 3 (CH 2 ) 3 NH 2', 'journal_publication': 'nature', 'date_published': 'JANUARY 2021'}, {'treated_pce': '24.5', 'control_pce': '21'}, {'structure_pin_nip': 'NIP', 'perovskite_molecule': 'iso-butylammonium', 'electron_transport_layer': ['C60', 'C 60'], 'perovskite_composition': 'FA(MA)PbI 3', 'hole_transport_layer': 'Spiro-OMeTAD', 'treated_voc': '1.135', 'treated_pce': '22.1'}, {'perovskite_molecule': 'phenethylammonium iodide', 'perovskite_composition': 'MAPbI3', 'ISOSD1': {'time': '240', 'treated_pce': '15.3', 'control_pce': '16.69', 'temperature': '25', 'humidity': '90', 'control_voc': '1.03', 'treated_voc': '1.06'}, 'electron_transport_layer': 'TiO2', 'hole_transport_layer': 'Spiro-OMeTAD'}, {'ISOSL1': {'temperature': 'room_temperature', 'control_pce': '10', 'treated_pce': '15.42', 'treated_voc': '1.45', 'efficiency_tret': '0.9', 'time': '1000', 'humidity': '65'}, 'structure_pin_nip': 'NIP', 'electron_transport_layer': 'C60', 'perovskite_molecule': 'phenylethylammonium', 'perovskite_composition': '2 (FA) 8 Sn 9 I 2'}, {'temperature': 'NIP', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'ISOSL1': {'control_pce': '20.1', 'treated_pce': '23.0', 'temperature': '40', 'time': '2000', 'efficiency_tret': '0.85', 'efficiency_cont': '0.60', 'control_voc': '1.160', 'treated_voc': '1.177'}, 'perovskite_molecule': 'ethylammonium'}, {'perovskite_molecule': 'diammonium iodide', 'perovskite_composition': 'CH3NH3PbI3', 'electron_transport_layer': ['NiO', 'PCBM'], 'structure_pin_nip': 'PIN', 'treated_pce': '17.60', 'control_pce_peak': '14.64', 'control_voc': '1.08', 'treated_voc': '1.10'}, {'perovskite_molecule': 'octylammonium tosylate', 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'structure_pin_nip': 'n-i-p', 'perovskite_composition': '(FAPbI3)0.95(MAPbBr3)0.05', 'ISOSL1': {'treated_pce': '24.41', 'temperature': '40', 'efficiency_cont': '0.651', 'efficiency_tret': '0.885', 'time': '2,092'}}, {'structure_pin_nip': ['benzotriazole', 'n-i-p'], 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'Spiro-OMeTAD', 'ISOSL1': {'temperature': 'room temperature', 'control_pce': '20.2', 'control_voc': '1.11', 'treated_voc': '1.16', 'treated_pce': '21.8', 'time': '24', 'efficiency_cont': '0.98', 'efficiency_tret': '1.04'}}, {'perovskite_molecule': 'butylammonium bromide', 'ISOSL1': {'control_voc': '1.24', 'treated_voc': '1.31', 'treated_pce': '19.8', 'efficiency_cont': '1.0', 'efficiency_tret': '1.0', 'time': '20', 'temperature': '25', 'control_pce': '17.5'}, 'electron_transport_layer': 'SnO2', 'hole_transport_layer': 'spiro-OMeTAD', 'structure_pin_nip': 'NIP', 'perovskite_composition': 'Cs0.15FA0.85PbI2.19Br0.81'}, {'passivating_molecule': '2-thiopheneethylammonium chloride', 'ISOSL2': {'control_voc': '1.29', 'treated_pce': '23.8', 'temperature': '60', 'efficiency_tret': '0.92', 'efficiency_cont': '0.82', ...
#                                               ISOSL3 structure_pin_nip  \
# 0  {'control_pce': '24', 'efficiency_tret': '95%'...               PIN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NIP
#
#               passivating_molecule        perovskite_composition  \
# 0                          4Cl-BZS  Cs 0.05 FA 0.85 MA 0.1 PbI 3
# 1  phenethylammonium iodide (PEAI)                           NaN
# 2             (CH 3 (CH 2 ) 3 NH 2       (C 4 H 9 NH 3 ) 2 PbI 4
# 3                              NaN                           NaN
# 4                              NaN                   FA(MA)PbI 3
#
#   hole_transport_layer         electron_transport_layer journal_publication  \
# 0   2PACz and Me-4PACz                              C60  [Science, science]
# 1         spiro-OMeTAD  [HC(NH 2 ) 2 -CH 3 NH 3, SnO 2]              nature
# 2         Spiro-OMeTAD                             SnO2              nature
# 3                  NaN                              NaN                 NaN
# 4         Spiro-OMeTAD                      [C60, C 60]                 NaN
#
#   date_published                                             ISOSD2  \
# 0      4/11/2024                                                NaN
# 1   1 April 2019  {'treated_pce': '23.32', 'treated_voc': '1.16'...
# 2   JANUARY 2021                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
#
#   treated_voc  ... ISOSL2 time efficiency_cont treated_pce_peak  \
# 0         NaN  ...    NaN  NaN             NaN              NaN
# 1         NaN  ...    NaN  NaN             NaN              NaN
# 2       1.185  ...    NaN  NaN             NaN              NaN
# 3         NaN  ...    NaN  NaN             NaN              NaN
# 4       1.135  ...    NaN  NaN             NaN              NaN
#
#   control_voc_peak treated_voc_peak ISOST2 ISOST1 control_pce_average  \
# 0              NaN              NaN    NaN    NaN                 NaN
# 1              NaN              NaN    NaN    NaN                 NaN
# 2              NaN              NaN    NaN    NaN                 NaN
# 3              NaN              NaN    NaN    NaN                 NaN
# 4              NaN              NaN    NaN    NaN                 NaN
#
#   treated_pce_average
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 30 columns]

# %%
df[df['treated_pce_peak'].isna() == False]
# Out:
#    ISOSL3 structure_pin_nip            passivating_molecule  \
# 23    NaN               NaN  tri-n-octylphosphine (TOPO) 26
# 37    NaN               PIN                             NaN
# 53    NaN               NaN                             NaN
#
#                                perovskite_composition hole_transport_layer  \
# 23                                                NaN                  NaN
# 37  [PCBM, choline chloride, FA 0.85 MA 0.15 Pb(I ...                  NaN
# 53                                                NaN     [PEDOT:PSS, NiO]
#
#        electron_transport_layer journal_publication date_published ISOSD2  \
# 23                          NaN                 NaN            NaN    NaN
# 37                          NaN                 NaN            NaN    NaN
# 53  [C60, C 60, BCP, Cu, SnO 2]                 NaN            NaN    NaN
#
#    treated_voc  ... ISOSL2   time efficiency_cont treated_pce_peak  \
# 23         NaN  ...    NaN    NaN             NaN           19.22%
# 37        QAHs  ...    NaN    NaN             NaN             QUAs
# 53         NaN  ...    NaN  600 h             NaN             26.7
#
#    control_voc_peak                        treated_voc_peak ISOST2 ISOST1  \
# 23              NaN                                     NaN    NaN    NaN
# 37              NaN  [L-α-phosphatidylcholine, 16.1 ± 1.1%]    NaN    NaN
# 53              NaN                                     NaN    NaN    NaN
#
#    control_pce_average treated_pce_average
# 23                 NaN                 NaN
# 37                 NaN                 NaN
# 53                  22               26.4%
#
# [3 rows x 30 columns]

# %%
df.to_csv("../../data/bioc_parsed.csv", index=False)

# %% [markdown]
# ## Building Training Data

# %%
training_data = []
txt_dir = "../../data/txts"
for filename in os.listdir(bioc_dir):
    if filename.endswith(".xml"):
        file_path = os.path.join(bioc_dir, filename)
        tree = ET.parse(file_path)
        root = tree.getroot()
        annotations = root.findall(".//annotation")
        if len(annotations) == 0: # has not been annotated yet
            continue
        paper_number = root.find(".//passage").find("text").text
        paper_number = paper_number.split(": ")[1]
        txt_filepath = os.path.join(txt_dir, f"{paper_number}.txt")
        with open(txt_filepath, "r", encoding="utf-8") as f:
            unannotated = f.read()
        with open(file_path, "r", encoding="utf-8") as f:
            xml_text = f.read()
        row = { "paper_id": paper_number, "unannotated": unannotated, "annotated": xml_text }
        training_data.append(row)
df = pd.DataFrame(training_data)
df.to_csv("../../data/training_data.csv", index=False)
df.head()
# Out:
#   paper_id                                        unannotated  \
# 0        0  Paper #: 0\nInterfacial engineering from mater...
# 1        1  Paper #: 1\nSurface passivation of perovskite ...
# 2        2  Paper #: 2\nIntact 2D/3D halide junction perov...
# 3        3  Paper #: 3\nDeterministic fabrication of 3D/2D...
# 4        5  Paper #: 5\nFront-contact passivation through ...
#
#                                            annotated
# 0  <?xml version="1.0" encoding="UTF-8"?>\n<!DOCT...
# 1  <?xml version="1.0" encoding="UTF-8"?>\n<!DOCT...
# 2  <?xml version="1.0" encoding="UTF-8"?>\n<!DOCT...
# 3  <?xml version="1.0" encoding="UTF-8"?>\n<!DOCT...
# 4  <?xml version="1.0" encoding="UTF-8"?>\n<!DOCT...
