# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib
import requests
from urllib.parse import urlparse
from io import BytesIO
import pymupdf
import os
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import tempfile

# %% [markdown]
# ## Loading in dataset

# %%
good_papers = pd.read_csv("../../data/150_research_papers.csv")

# %% [markdown]
# ## Scraping with Selenium

# %%
download_dir = tempfile.mkdtemp()
chrome_options = uc.ChromeOptions()
chrome_options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,  # Set download location
    "download.prompt_for_download": False,       # Disable download prompts
    "plugins.always_open_pdf_externally": True   # Download PDFs instead of opening them
})
driver = uc.Chrome()

# %%
def get_base_url(url):
    """Gets the base url from a given url (i.e. https://www.nature.com)"""
    parsed = urlparse(url)
    return f"{parsed.scheme}://{parsed.netloc}"

# %%
def download_pdf_urls(url, paper_index):
    driver.get(url)

    pdf_links = []
    for link in driver.find_elements(By.TAG_NAME, "a"):
        try:
            href = link.get_attribute("href")
            if href and "pdf" in href and href not in pdf_links:
                pdf_links.append(href)
        except:
            print(f"Failed to get link {link}")
    merged_pdf = pymupdf.open()
    i = 0
    print(pdf_links)
    for pdf_link in pdf_links:
        # Ensure each link is a full URL
        pdf_url = pdf_link if pdf_link.startswith('http') else get_base_url(url) + pdf_link
        print(pdf_url)
        try:
            driver.get(pdf_url)
            print(f"Processing PDF URL: {pdf_url}")
        except:
            print(f"Skipping invalid PDF at {pdf_url}")
            continue
        
        # Load PDF content into a PyMuPDF document
        
    pdf_files = [os.path.join(download_dir, f) for f in os.listdir(download_dir) if f.endswith('.pdf')]
    output_path = f'../../data/pdfs/{paper_index}.pdf'
    for pdf in pdf_files:
        merged_pdf.insert_pdf(pdf)
    merged_pdf.save(output_path)
    merged_pdf.close()
    print(f"Merged PDF saved as {output_path}")
    return pdf_links

# %%
for index, row in good_papers.iterrows():
    download_pdf_urls(row['Link'], index)
# Out:
# ['https://www.science.org/doi/suppl/10.1126/science.adm9474/suppl_file/science.adm9474_sm.pdf', 'https://www.science.org/doi/pdf/10.1126/science.adm9474?download=true', 'https://www.science.org/doi/pdf/10.1126/science.adm9474', 'https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.adm9474&hl=en&sa=T&oi=ucasa&ct=usl&ei=EmssZ6ihHYiCy9YP4Mv8gAQ&scisig=AFWwaeYRg15SCPRBFYOXij0FEX0x']
# https://www.science.org/doi/suppl/10.1126/science.adm9474/suppl_file/science.adm9474_sm.pdf
# Processing PDF URL: https://www.science.org/doi/suppl/10.1126/science.adm9474/suppl_file/science.adm9474_sm.pdf
# Skipping invalid PDF at https://www.science.org/doi/suppl/10.1126/science.adm9474/suppl_file/science.adm9474_sm.pdf: Failed to open stream
# https://www.science.org/doi/pdf/10.1126/science.adm9474?download=true
# Processing PDF URL: https://www.science.org/doi/pdf/10.1126/science.adm9474?download=true
# Skipping invalid PDF at https://www.science.org/doi/pdf/10.1126/science.adm9474?download=true: Failed to open stream
# https://www.science.org/doi/pdf/10.1126/science.adm9474
# Processing PDF URL: https://www.science.org/doi/pdf/10.1126/science.adm9474
# Skipping invalid PDF at https://www.science.org/doi/pdf/10.1126/science.adm9474: Failed to open stream
# https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.adm9474&hl=en&sa=T&oi=ucasa&ct=usl&ei=EmssZ6ihHYiCy9YP4Mv8gAQ&scisig=AFWwaeYRg15SCPRBFYOXij0FEX0x
# Processing PDF URL: https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.adm9474&hl=en&sa=T&oi=ucasa&ct=usl&ei=EmssZ6ihHYiCy9YP4Mv8gAQ&scisig=AFWwaeYRg15SCPRBFYOXij0FEX0x
# Skipping invalid PDF at https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science
Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/jacs.5b11740/suppl_file/ja5b11740_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/jacs.5b11740/suppl_file/ja5b11740_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/jacs.5b11740/suppl_file/ja5b11740_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/jacs.5b11740/suppl_file/ja5b11740_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/jacs.5b11740/suppl_file/ja5b11740_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/jacs.5b11740/suppl_file/ja5b11740_si_001.pdf: Failed to open stream
# No PDF links found for index 6.
# ['https://pubs.acs.org/doi/epdf/10.1021/acs.chemrev.0c01006?ref=article_openPDF', 'https://pubs.acs.org/doi/pdf/10.1021/acs.chemrev.0c01006']
# https://pubs.acs.org/doi/epdf/10.1021/acs.chemrev.0c01006?ref=article_openPDF
# Processing PDF URL: https://pubs.acs.org/doi/epdf/10.1021/acs.chemrev.0c01006?ref=article_openPDF
# Skipping invalid PDF at https://pubs.acs.org/doi/epdf/10.1021/acs.chemrev.0c01006?ref=article_openPDF: Failed to open stream
# https://pubs.acs.org/doi/pdf/10.1021/acs.chemrev.0c01006
# Processing PDF URL: https://pubs.acs.org/doi/pdf/10.1021/acs.chemrev.0c01006
# Skipping invalid PDF at https://pubs.acs.org/doi/pdf/10.1021/acs.chemrev.0c01006: Failed to open stream
# No PDF links found for index 7.
# ['https://www.science.org/doi/suppl/10.1126/science.abd4860/suppl_file/abd4860_xue_sm.pdf', 'https://www.science.org/doi/pdf/10.1126/science.abd4860?download=true', 'https://www.science.org/doi/pdf/10.1126/science.abd4860', 'https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.abd4860&hl=en&sa=T&oi=ucasa&ct=usl&ei=cm0sZ9yjFb3Py9YPzO-msQY&scisig=AFWwaeb5uOrQjzNTh2nOnJDlCSnV']
# https://www.science.org/doi/suppl/10.1126/science.abd4860/suppl_file/abd4860_xue_sm.pdf
# Processing PDF URL: https://www.science.org/doi/suppl/10.1126/science.abd4860/suppl_file/abd4860_xue_sm.pdf
# Skipping invalid PDF at https://www.science.org/doi/suppl/10.1126/science.abd4860/suppl_file/abd4860_xue_sm.pdf: Failed to open stream
# https://www.science.org/doi/pdf/10.1126/science.abd4860?download=true
# Processing PDF URL: https://www.science.org/doi/pdf/10.1126/science.abd4860?download=true
# Skipping invalid PDF at https://www.science.org/doi/pdf/10.1126/science.abd4860?download=true: Failed to open stream
# https://www.science.org/doi/pdf/10.1126/science.abd4860
# Processing PDF URL: https://www.science.org/doi/pdf/10.1126/science.abd4860
# Skipping invalid PDF at https://www.science.org/doi/pdf/10.1126/science.abd4860: Failed to open stream
# https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.abd4860&hl=en&sa=T&oi=ucasa&ct=usl&ei=cm0sZ9yjFb3Py9YPzO-msQY&scisig=AFWwaeb5uOrQjzNTh2nOnJDlCSnV
# Processing PDF URL: https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.abd4860&hl=en&sa=T&oi=ucasa&ct=usl&ei=cm0sZ9yjFb3Py9YPzO-msQY&scisig=AFWwaeb5uOrQjzNTh2nOnJDlCSnV
# Skipping invalid PDF at https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.abd4860&hl=en&sa=T&oi=ucasa&ct=usl&ei=cm0sZ9yjFb3Py9YPzO-msQY&scisig=AFWwaeb5uOrQjzNTh2nOnJDlCSnV: Failed to open stream
# No PDF links found for index 8.
# ['https://pubs.acs.org/doi/epdf/10.1021/acsenergylett.6b00327?ref=article_openPDF', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/pdf/10.1021/acsenergylett.6b00327', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf']
# https://pubs.acs.org/doi/epdf/10.1021/acsenergylett.6b00327?ref=article_openPDF
# Processing PDF URL: https://pubs.acs.org/doi/epdf/10.1021/acsenergylett.6b00327?ref=article_openPDF
# Skipping invalid PDF at https://pubs.acs.org/doi/epdf/10.1021/acsenergylett.6b00327?ref=article_openPDF: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/pdf/10.1021/acsenergylett.6b00327
# Processing PDF URL: https://pubs.acs.org/doi/pdf/10.1021/acsenergylett.6b00327
# Skipping invalid PDF at https://pubs.acs.org/doi/pdf/10.1021/acsenergylett.6b00327: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.6b00327/suppl_file/nz6b00327_si_001.pdf: Failed to open stream
# No PDF links found for index 9.
# ['https://www.nature.com/articles/s41586-022-04604-5.pdf', 'https://www.nature.com/articles/s41586-022-04604-5.pdf', 'https://static-content.springer.com/esm/art%3A10.1038%2Fs41586-022-04604-5/MediaObjects/41586_2022_4604_MOESM1_ESM.pdf', 'https://www.nature.com/articles/s41586-022-04604-5.pdf']
# https://www.nature.com/articles/s41586-022-04604-5.pdf
# Processing PDF URL: https://www.nature.com/articles/s41586-022-04604-5.pdf
# https://www.nature.com/articles/s41586-022-04604-5.pdf
# Processing PDF URL: https://www.nature.com/articles/s41586-022-04604-5.pdf
# https://static-content.springer.com/esm/art%3A10.1038%2Fs41586-022-04604-5/MediaObjects/41586_2022_4604_MOESM1_ESM.pdf
# Processing PDF URL: https://static-content.springer.com/esm/art%3A10.1038%2Fs41586-022-04604-5/MediaObjects/41586_2022_4604_MOESM1_ESM.pdf
# https://www.nature.com/articles/s41586-022-04604-5.pdf
# Processing PDF URL: https://www.nature.com/articles/s41586-022-04604-5.pdf
# Merged PDF saved as '../../data/pdfs/10.pdf'
# ['https://pubs.acs.org/doi/epdf/10.1021/acsaem.3c00101?ref=article_openPDF', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/pdf/10.1021/acsaem.3c00101', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf', 'https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf']
# https://pubs.acs.org/doi/epdf/10.1021/acsaem.3c00101?ref=article_openPDF
# Processing PDF URL: https://pubs.acs.org/doi/epdf/10.1021/acsaem.3c00101?ref=article_openPDF
# Skipping invalid PDF at https://pubs.acs.org/doi/epdf/10.1021/acsaem.3c00101?ref=article_openPDF: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/pdf/10.1021/acsaem.3c00101
# Processing PDF URL: https://pubs.acs.org/doi/pdf/10.1021/acsaem.3c00101
# Skipping invalid PDF at https://pubs.acs.org/doi/pdf/10.1021/acsaem.3c00101: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsaem.3c00101/suppl_file/ae3c00101_si_001.pdf: Failed to open stream
# No PDF links found for index 11.
# ['https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699', 'https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699', 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.201803699&file=aenm201803699-sup-0001-S1.pdf', 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.201803699']
# https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699
# Processing PDF URL: https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699
# Skipping invalid PDF at https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699: Failed to open stream
# https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699
# Processing PDF URL: https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699
# Skipping invalid PDF at https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.201803699: Failed to open stream
# https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.201803699&file=aenm201803699-sup-0001-S1.pdf
# Processing PDF URL: https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.201803699&file=aenm201803699-sup-0001-S1.pdf
# Skipping invalid PDF at https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.201803699&file=aenm201803699-sup-0001-S1.pdf: Failed to open stream
# https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.201803699
# Processing PDF URL: https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.201803699
# Skipping invalid PDF at https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.201803699: Failed to open stream
# No PDF links found for index 12.
# ['https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438', 'https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438', 'https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.202202438&file=aenm202202438-sup-0001-SuppMat.pdf', 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.202202438']
# https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438
# Processing PDF URL: https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438
# Skipping invalid PDF at https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438: Failed to open stream
# https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438
# Processing PDF URL: https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438
# Skipping invalid PDF at https://onlinelibrary.wiley.com/doi/epdf/10.1002/aenm.202202438: Failed to open stream
# https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.202202438&file=aenm202202438-sup-0001-SuppMat.pdf
# Processing PDF URL: https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.202202438&file=aenm202202438-sup-0001-SuppMat.pdf
# Skipping invalid PDF at https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Faenm.202202438&file=aenm202202438-sup-0001-SuppMat.pdf: Failed to open stream
# https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.202202438
# Processing PDF URL: https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.202202438
# Skipping invalid PDF at https://onlinelibrary.wiley.com/doi/pdf/10.1002/aenm.202202438: Failed to open stream
# No PDF links found for index 13.
# ['https://www.science.org/doi/suppl/10.1126/sciadv.abj7930/suppl_file/sciadv.abj7930_sm.pdf', 'https://scholar.google.com/scholar?q=National+Renewable+Energy+Laboratory%2C+NREL_efficiencies_chart.pdf+%282021%29.', 'https://www.science.org/doi/pdf/10.1126/sciadv.abj7930?download=true', 'https://scholar.google.com/scholar?q=National+Renewable+Energy+Laboratory%2C+NREL_efficiencies_chart.pdf+%282021%29.', 'https://www.science.org/doi/pdf/10.1126/sciadv.abj7930', 'https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126
://www.nrel.gov/pv/assets/pdfs/best-research-cell-efficiencies.20190802.pdf
# http://scholar.google.com/scholar?hl=en&q=NREL.+Best+Research-Cell+Efficiences.+https%3A%2F%2Fwww.nrel.gov%2Fpv%2Fassets%2Fpdfs%2Fbest-research-cell-efficiencies.20190802.pdf%2C+%28accessed+October+8%2C+2019%29.
# Processing PDF URL: https://scholar.google.com/scholar?hl=en&q=NREL.+Best+Research-Cell+Efficiences.+https%3A%2F%2Fwww.nrel.gov%2Fpv%2Fassets%2Fpdfs%2Fbest-research-cell-efficiencies.20190802.pdf%2C+%28accessed+October+8%2C+2019%29.
# Skipping invalid PDF at http://scholar.google.com/scholar?hl=en&q=NREL.+Best+Research-Cell+Efficiences.+https%3A%2F%2Fwww.nrel.gov%2Fpv%2Fassets%2Fpdfs%2Fbest-research-cell-efficiencies.20190802.pdf%2C+%28accessed+October+8%2C+2019%29.: Failed to open stream
# https://pubs.acs.org/doi/pdf/10.1021/acsenergylett.9b02348
# Processing PDF URL: https://pubs.acs.org/doi/pdf/10.1021/acsenergylett.9b02348
# Skipping invalid PDF at https://pubs.acs.org/doi/pdf/10.1021/acsenergylett.9b02348: Failed to open stream
# https://www.nrel.gov/pv/assets/pdfs/best-research-cell-efficiencies.20190802.pdf
# Processing PDF URL: https://www.nrel.gov/pv/assets/pdfs/best-research-cell-efficiencies.20190802.pdf
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.9b02348/suppl_file/nz9b02348_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.9b02348/suppl_file/nz9b02348_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.9b02348/suppl_file/nz9b02348_si_001.pdf: Failed to open stream
# https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.9b02348/suppl_file/nz9b02348_si_001.pdf
# Processing PDF URL: https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.9b02348/suppl_file/nz9b02348_si_001.pdf
# Skipping invalid PDF at https://pubs.acs.org/doi/suppl/10.1021/acsenergylett.9b02348/suppl_file/nz9b02348_si_001.pdf: Failed to open stream
# Merged PDF saved as '../../data/pdfs/103.pdf'
# ['https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm-revised.pdf', 'https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm.pdf', 'https://www.science.org/doi/pdf/10.1126/science.aay7044?download=true', 'https://www.science.org/doi/pdf/10.1126/science.aay7044', 'https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.aay7044&hl=en&sa=T&oi=ucasa&ct=usl&ei=WXQsZ-WTGb3Py9YPzO-msQY&scisig=AFWwaeaVTCJYU9gCnPmEvgs4Jn2J']
# https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm-revised.pdf
# Processing PDF URL: https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm-revised.pdf
# Skipping invalid PDF at https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm-revised.pdf: Failed to open stream
# https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm.pdf
# Processing PDF URL: https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm.pdf
# Skipping invalid PDF at https://www.science.org/doi/suppl/10.1126/science.aay7044/suppl_file/aay7044-min-sm.pdf: Failed to open stream
# https://www.science.org/doi/pdf/10.1126/science.aay7044?download=true
# Processing PDF URL: https://www.science.org/doi/pdf/10.1126/science.aay7044?download=true
# Skipping invalid PDF at https://www.science.org/doi/pdf/10.1126/science.aay7044?download=true: Failed to open stream
# https://www.science.org/doi/pdf/10.1126/science.aay7044
# Processing PDF URL: https://www.science.org/doi/pdf/10.1126/science.aay7044
# Skipping invalid PDF at https://www.science.org/doi/pdf/10.1126/science.aay7044: Failed to open stream
# https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.aay7044&hl=en&sa=T&oi=ucasa&ct=usl&ei=WXQsZ-WTGb3Py9YPzO-msQY&scisig=AFWwaeaVTCJYU9gCnPmEvgs4Jn2J
# Processing PDF URL: https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.aay7044&hl=en&sa=T&oi=ucasa&ct=usl&ei=WXQsZ-WTGb3Py9YPzO-msQY&scisig=AFWwaeaVTCJYU9gCnPmEvgs4Jn2J
# Skipping invalid PDF at https://scholar.google.com/scholar_url?url=https://www.science.org/doi/pdf/10.1126/science.aay7044&hl=en&sa=T&oi=ucasa&ct=usl&ei=WXQsZ-WTGb3Py9YPzO-msQY&scisig=AFWwaeaVTCJYU9gCnPmEvgs4Jn2J: Failed to open stream
# No PDF links found for index 104.
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[15], line 2
#       1 for index, row in good_papers.iterrows():
# ----> 2     download_pdf_urls(row['Link'], index)
#
# Cell In[14], line 5, in download_pdf_urls(url, paper_index)
#       2 driver.get(url)
#       4 pdf_links = []
# ----> 5 for link in driver.find_elements(By.TAG_NAME, "a"):
#       6     try:
#       7         href = link.get_attribute("href")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:788, in WebDriver.find_elements(self, by, value)
#     784     return self.execute_script(find_element_js, by.to_dict())
#     786 # Return empty list if driver returns null
#     787 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 788 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:380, in WebDriver.execute(self, driver_command, params)
#     378 response = self.command_executor.execute(driver_command, params)
#     379 if response:
# --> 380     self.error_handler.check_response(response)
#     381     response["value"] = self._unwrap_value(response.get("value", None))
#     382     return response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=130.0.6723.92)
# Stacktrace:
# 	GetHandleVerifier [0x008AEBD3+24307]
# 	(No symbol) [0x00838D74]
# 	(No symbol) [0x0071C323]
# 	(No symbol) [0x0070CA18]
# 	(No symbol) [0x0070C939]
# 	(No symbol) [0x0071E790]
# 	(No symbol) [0x00798EE9]
# 	(No symbol) [0x0077FC26]
# 	(No symbol) [0x0075219C]
# 	(No symbol) [0x0075311D]
# 	GetHandleVerifier [0x00B58D93+2818227]
# 	GetHandleVerifier [0x00BB542E+3196750]
# 	GetHandleVerifier [0x00BAD9D2+3165426]
# 	GetHandleVerifier [0x0094DA70+675216]
# 	(No symbol) [0x00841B3D]
# 	(No symbol) [0x0083EA18]
# 	(No symbol) [0x0083EBB5]
# 	(No symbol) [0x00831640]
# 	BaseThreadInitThunk [0x76977BA9+25]
# 	RtlInitializeExceptionChain [0x7775C0CB+107]
# 	RtlClearBits [0x7775C04F+191]

# %% [markdown]
# ## Making PDFs of each paper

# %%
def get_base_url(url):
    """Gets the base url from a given url (i.e. https://www.nature.com)"""
    parsed = urlparse(url)
    return f"{parsed.scheme}://{parsed.netloc}"

# %%
def get_page(url):
    """Gets the content of a given url with user headers"""
    req = urllib.request.Request(url)
    req.add_header('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:106.0) Gecko/20100101 Firefox/106.0')
    req.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8')
    req.add_header('Accept-Language', 'en-US,en;q=0.5')

    r = urllib.request.urlopen(req)
    return r

# %%
def get_actual_url(url):
    """Gets the url after redirection for a given url"""
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
    r = requests.get(url, headers=headers, allow_redirects=True)
    parsed_uri = urlparse(r.url)
    print(r.url)
    return f'{parsed_uri.scheme}://{parsed_uri.netloc}/'

# %%
def reset_eof(pdf_content):
    """Some PDFs have an early EOF marker, which confuses PyMuPDF, 
    this moves it to the end of the file. Sometimes there is no EOF marker, 
    so we add one."""
    # find the line position of the EOF
    EOF_MARKER = b'%%EOF'
    if EOF_MARKER in pdf_content:
        # we can remove the early %%EOF and put it at the end of the file
        pdf_content = pdf_content.replace(EOF_MARKER, b'')
        pdf_content = pdf_content + EOF_MARKER
    else:
        # Some files really don't have an EOF marker
        # printed b'\n%%EO%E'
        pdf_content = pdf_content[:-6] + EOF_MARKER
    return pdf_content

# %%
def download_all_pdfs(url, paper_index):
    """Finds and downloads all pdfs for a given paper. 
    Uses PyMuPDF to download and merge all pdfs on the page into one."""
    page = get_page(url)
    url = get_actual_url(url)
    print(url)
    soup = BeautifulSoup(page.read().decode("utf-8"), 'html.parser')
    
    # Find all unique PDF links on the page
    pdf_links = [link.get('href') for link in soup.find_all('a', href=True) \
                 if link.get('href') and 'pdf' in urlparse(link.get('href')).path.lower()]
    pdf_links = list(set(pdf_links))
    
    # Initialize a new PDF document to store the merged pages
    merged_pdf = pymupdf.open()
    i = 0
    print(pdf_links)
    for pdf_link in pdf_links:
        # Ensure each link is a full URL
        pdf_url = pdf_link if pdf_link.startswith('http') else get_base_url(url) + pdf_link
        print(pdf_url)
        try:
            res = requests.get(pdf_url, allow_redirects=True)
            print(f"Processing PDF URL: {res.url}")
        except:
            print(f"Skipping invalid PDF at {pdf_url}")
            continue
        
        # Load PDF content into a PyMuPDF document
        try:
            pdf_stream = BytesIO(res.content)
            pdf_document = pymupdf.open(stream=pdf_stream, filetype="pdf")
            
            # Append each page to the merged PDF
            for page_num in range(pdf_document.page_count):
                merged_pdf.insert_pdf(pdf_document, from_page=page_num, to_page=page_num)
                
            pdf_document.close()
            i += 1
        except Exception as e:
            print(f"Skipping invalid PDF at {pdf_url}: {e}")
    
    # Save the merged PDF to disk
    if (merged_pdf.page_count > 0):
        merged_pdf.save(f'../data/pdfs/{paper_index}.pdf')
        merged_pdf.close()
        print(f"Merged PDF saved as '../data/pdfs/{paper_index}.pdf'")
    else:
        print(f"No PDF links found for index {paper_index}.")
        #TODO : use selenium to download the pdf by printing

# %%
#creating pdfs for each row in the merged dataframe
for index, row in merged_df.iterrows():
    print(row['link'])
    download_all_pdfs(row['link'], index)

# %%
existing_files = {os.path.splitext(file)[0] for file in os.listdir('../data/pdfs')}
for index, row in merged_df.iterrows():
    index_str = str(index)
    if index_str not in existing_files:
        #showing which pdf prints were not successful (done manually for now, will be done with Selenium later)
        print(index)
        print(row['link'])
# Out:
# 38
# https://pubs.rsc.org/en/content/articlehtml/2019/ta/c9ta01070j
# 39
# https://pubs.rsc.org/en/content/articlehtml/2019/ee/c9ee00453j
# 71
# https://doi.org/10.48550/arXiv.2102.10399
# 74
# https://doi.org/10.1146/annurev-food-022814-015651
# 76
# https://doi.org/10.1039/C9CS00711C
# 82
# https://doi.org/10.1039/TF937330008B
# 90
# https://doi.org/10.1039%2FC7TA00434F
# 97
# https://doi.org/10.1017/CBO9780511608810
# 100
# https://doi.org/10.1146/annurev.bb.12.060183.001035
# 105
# https://doi.org/10.1146/annurev.physchem.51.1.209
# 120
# https://doi.org/10.1039/D1SM01707A
# 125
# https://doi.org/10.1039%2FC4TA05033A
# 128
# https://doi.org/10.1146/annurev.ms.12.080182.000535
# 129
# https://doi.org/10.1039/DC9786500007

# %% [markdown]
# ## Convert PDFs to XML using GROBID

# %%
grobid_url = "http://localhost:8070/api/processFulltextDocument"
xml_names = os.listdir("../data/xmls")

for pdf_file in os.listdir("../data/pdfs"):
    #only looks at pdf files
    if pdf_file.endswith(".pdf"):
        pdf_path = os.path.join("../data/pdfs", pdf_file)
        #doe not convert already converted files
        if pdf_path.replace('.pdf', '.xml') in xml_names:
            continue
        with open(pdf_path, 'rb') as file:
            #GROBID must be running on port 8070 for this to work
            response = requests.post(
                grobid_url,
                files={'input': file},
                headers={'Accept': 'application/xml'}
            )

            if response.status_code == 200:
                xml_file_path = os.path.join('../data/xmls', pdf_file.replace('.pdf', '.xml'))
                with open(xml_file_path, 'w', encoding='utf-8') as xml_file:
                    xml_file.write(response.text)
                print(f"Converted {pdf_file} to XML.")
            else:
                print(f"Failed to convert {pdf_file}. Status code: {response.status_code}")
                print(response.text)
