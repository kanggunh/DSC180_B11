# %%
import chemdataextractor
print("CDE is working in the conda environment!")
# Out:
# CDE is working in the conda environment!

# %%
from chemdataextractor import Document

# Sample text

with open('0.xml', 'r') as file:
    xml_text = file.read()

# Step 2: Pass the XML text directly into ChemDataExtractor
doc = Document(xml_text)

# f = open('0.xml', 'rb')

# doc = Document.from_file(f)

# Extract entities from each sentence in the document
doc.elements[0][1:5]
# Out:
# [Sentence('The energetic losses responsible for this PCE deficit in pin PSCs occur primarily at the interfaces between the perovskite and the charge-transport layers.', 17901, 18056),
#  Sentence('Additive and surface treatments that use passivating ligands usually bind to a single active binding site: This dense packing of electrically resistive passivants perpendicular to the surface may limit the fill factor in pin PSCs.', 18057, 18287),
#  Sentence('We identified ligands that bind two neighboring lead(II) ion (Pb 2+ ) defect sites in a planar ligand orientation on the perovskite.', 18288, 18420),
#  Sentence('We fabricated pin PSCs and report a certified quasi-steady state PCE of 26.15 and 24.74% for 0.05-and 1.04-square centimeter illuminated areas, respectively.', 18421, 18578)]

# %%
#doc.elements

# %%
doc.records.serialize()
# Out:
# [{'names': ['V8P']},
#  {'names': ['lead(II)']},
#  {'names': ['ammonium']},
#  {'names': ['-PO 3 2-and -SO']},
#  {'names': ['benzenephosphonates']},
#  {'names': ['sulfonates']},
#  {'names': ['oxygen']},
#  {'names': ['formamidinium (FA)-based perovskites']},
#  {'names': ['methyl']},
#  {'names': ['chloride']},
#  {'names': ['[ 4-methylbenzenesulfonate ( 4CH 3 -BZS ) and 4-chlorobenzenesulfonate']},
#  {'names': ['4CH 3 -BZS and']},
#  {'names': ['formamidinium']},
#  {'names': ['methylamine']},
#  {'names': ['fluorinate tin oxide']},
#  {'names': ['2PACz']},
#  {'names': ['SnO']},
#  {'names': ['Pb-Sn']},
#  {'names': ['[2-(9H-Carbazol-9-yl)ethyl]phosphonic Acid']},
#  {'names': ['Sodium p-toluenesulfonate']},
#  {'names': ['Sodium 4-chlorobenzenesulfonate']},
#  {'names': ['N, N-dimethylformamide']},
#  {'names': ['C60, bathocuproine']},
#  {'names': ['1,3-propane diammonium iodide']},
#  {'names': ['hydroiodic acid']},
#  {'names': ['3MTPA']},
#  {'names': ['amines']},
# ...

# %%
doc.cems
# Out:
# [Span('Li', 79187, 79189),
#  Span('Br', 58940, 58942),
#  Span('persName', 95095, 95103),
#  Span('H', 204951, 204952),
#  Span('persName', 77102, 77110),
#  Span('persName', 108176, 108184),
#  Span('persName', 116764, 116772),
#  Span('perovskite', 140285, 140295),
#  Span('persName', 5560, 5568),
#  Span('Zakeeruddin', 189897, 189908),
#  Span('persName', 99300, 99308),
#  Span('persName', 161700, 161708),
#  Span('H', 54697, 54698),
#  Span('persName', 176971, 176979),
#  Span('perovskite-silicon', 163443, 163461),
#  Span('persName', 100183, 100191),
#  Span('perovskite', 32237, 32247),
#  Span('Cl', 26173, 26175),
#  Span('4Cl-BZS', 54880, 54887),
#  Span('Li', 171591, 171593),
#  Span('perovskite', 152030, 152040),
#  Span('nitrogen-filled', 43035, 43050),
#  Span('orgName', 11005, 11012),
#  Span('persName', 141843, 141851),
#  Span('listOrg', 73226, 73233),
#  Span('persName', 139365, 139373),
#  Span('persName', 145217, 145225),
#  Span('persName', 111381, 111389),
# ...
